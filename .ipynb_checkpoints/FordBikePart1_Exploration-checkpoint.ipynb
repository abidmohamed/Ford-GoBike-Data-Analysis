# %% [markdown]
# # Part I - (Project - Ford GoBike)
# ## by (Abid Mohamed Nadhir)

# %% [markdown]
# # 1. Introduction
#
# My chosen DataSet is showing information that covers over 180K records of individual rides made in a bike-sharing system covering the greater San Francisco Bay area in Feb-2019.
#
# This notebook is mainly aimed to answer some questions such as:
# * When are most trips taken in terms of time of day, day of the week, or month of the year?
# * How long does the average trip take?
# * Does the above depend on if a user is a subscriber or customer?
#
# to answer these questions we need some exploratory & explanatory data analysis techniques like visualization also some data wrangling skills.
# to solve the question we will use python as programming language and some libraries such as: Pandas, Matplotlib and Seaborn

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
#setting figure size
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 8,8
# set plot dimensions
plt.figure(figsize=[14, 6])

# %% [markdown]
# # 2. Data Wrangling

# %% [markdown]
# ## 2.1 Gathering

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-49a53dbe-47d0-4253-aab2-22fb163317e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49a53dbe-47d0-4253-aab2-22fb163317e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
filepath = "201902-fordgobike-tripdata.csv"
df = pd.read_csv(filepath)

# %% [markdown]
# ## 2.2 Assessing

# %%
df.head()
# Out:
#    duration_sec                start_time                  end_time  \
# 0         52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1         42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2         61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
# 3         36490  2019-02-28 17:54:26.0100  2019-03-01 04:02:36.8420
# 4          1585  2019-02-28 23:54:18.5490  2019-03-01 00:20:44.0740
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              23.0                     The Embarcadero at Steuart St
# 2              86.0                           Market St at Dolores St
# 3             375.0                           Grove St at Masonic Ave
# 4               7.0                               Frank H Ogawa Plaza
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183412 non-null  int64
#  1   start_time               183412 non-null  object
#  2   end_time                 183412 non-null  object
#  3   start_station_id         183215 non-null  float64
#  4   start_station_name       183215 non-null  object
#  5   start_station_latitude   183412 non-null  float64
#  6   start_station_longitude  183412 non-null  float64
#  7   end_station_id           183215 non-null  float64
#  8   end_station_name         183215 non-null  object
#  9   end_station_latitude     183412 non-null  float64
#  10  end_station_longitude    183412 non-null  float64
#  11  bike_id                  183412 non-null  int64
#  12  user_type                183412 non-null  object
# ...

# %% [markdown]
# *Some Null values can be viewed in birth_year, gender columns, stations (start, end).*

# %%
df.describe()
# Out:
#         duration_sec  start_station_id  start_station_latitude  \
# count  183412.000000     183215.000000           183412.000000
# mean      726.078435        138.590427               37.771223
# std      1794.389780        111.778864                0.099581
# min        61.000000          3.000000               37.317298
# 25%       325.000000         47.000000               37.770083
# 50%       514.000000        104.000000               37.780760
# 75%       796.000000        239.000000               37.797280
# max     85444.000000        398.000000               37.880222
#
#        start_station_longitude  end_station_id  end_station_latitude  \
# count            183412.000000   183215.000000         183412.000000
# mean               -122.352664      136.249123             37.771427
# std                   0.117097      111.515131              0.099490
# min                -122.453704        3.000000             37.317298
# ...

# %% [markdown]
# *Some member_birth_year values don't seem logical e.g min_value = 1878*

# %%
# Check null value for each column
df.isna().sum()
# Out:
# duration_sec                  0
# start_time                    0
# end_time                      0
# start_station_id            197
# start_station_name          197
# start_station_latitude        0
# start_station_longitude       0
# end_station_id              197
# end_station_name            197
# end_station_latitude          0
# end_station_longitude         0
# bike_id                       0
# user_type                     0
# member_birth_year          8265
# member_gender              8265
# bike_share_for_all_trip       0
# dtype: int64

# %%
# Check duplicated row
df.duplicated().sum()
# Out:
# 0

# %%
df.groupby(['member_birth_year'])['member_birth_year'].count().sort_values(ascending=True).head(40)
# Out:
# member_birth_year
# 1878.0       1
# 1928.0       1
# 1927.0       1
# 1910.0       1
# 1930.0       1
# 1944.0       2
# 1934.0       2
# 1920.0       3
# 1938.0       3
# 1901.0       6
# 1941.0       9
# 1939.0      11
# 1902.0      11
# 1946.0      19
# 1933.0      20
# 1942.0      21
# 1943.0      30
# 2001.0      34
# 1948.0      51
# 1900.0      53
# 1931.0      89
# 1949.0      99
# 1945.0     105
# 1955.0     134
# 1947.0     135
# 1953.0     158
# 1950.0     178
# 1951.0     180
# 1952.0     189
# 1954.0     301
# 1956.0     392
# 1958.0     517
# 1959.0     624
# 1957.0     807
# 1960.0     807
# 1961.0     821
# 1962.0     956
# 1966.0     989
# 1963.0    1151
# 1964.0    1189
# Name: member_birth_year, dtype: int64

# %%
df[df['member_birth_year']<1929]
# Out:
#         duration_sec                start_time                  end_time  \
# 1285             148  2019-02-28 19:29:17.6270  2019-02-28 19:31:45.9670
# 10827           1315  2019-02-27 19:21:34.4360  2019-02-27 19:43:30.0080
# 16087           1131  2019-02-27 08:37:36.8640  2019-02-27 08:56:28.0220
# 17981            366  2019-02-26 19:53:38.5280  2019-02-26 19:59:44.9680
# 18885            432  2019-02-26 17:48:59.0160  2019-02-26 17:56:11.3700
# ...              ...                       ...                       ...
# 173711           993  2019-02-03 09:45:30.4640  2019-02-03 10:02:04.1690
# 177708          1527  2019-02-01 19:09:28.3870  2019-02-01 19:34:55.9630
# 177885           517  2019-02-01 18:38:40.4710  2019-02-01 18:47:18.3920
# 182830           428  2019-02-01 07:45:05.9340  2019-02-01 07:52:14.9220
# 183388           490  2019-02-01 00:39:53.1120  2019-02-01 00:48:03.3380
#
#         start_station_id                                 start_station_name  \
# ...

# %%
# check for proportion of people born before 1920 
born_before_1929 = len(df[df['member_birth_year']<1929])
before_1929_percent = born_before_1929/len(df)
print (f'People who were born before 1929 represent {(before_1929_percent*100):.2f} %')
# Out:
# People who were born before 1929 represent 0.04 %

# %% [markdown]
# unlogical year of birth values 1901, 1902 or 1878 ...

# %%
# check for proportion of people born before 1920 
other_gender = len(df[df['member_gender']=='Other'])
other_gender_percent = other_gender/len(df)
print (f'People who were registred Other represent {(other_gender_percent*100):.2f} %')
# Out:
# People who were registred Other represent 1.99 %

# %% [markdown]
# ### Assessment Summary

# %% [markdown]
# * start_time and end_time columns in object dtype
# * start_station_id and end_station_id columns in int64 dtype
# * start_station_latitude, start_station_longitude, end_station_latitude, and end_station_longitude columns in float64 dtype
# * bike_id column in int64 dtype
# * user_type in object dtype
# * Adding Age column
# * drop NaN values
# * delete all ages Above 90 take into consideration the date of the data (2019)
# * Add day, week_day, hour, day_part columns from the start_time and end_time columns
# * Drop Gender Outliers "Other" since it represents less than 2%

# %% [markdown]
# ## 2.3 Cleaning
#
# In this section we will try to clean our data to make easier in visualization and exploration
# first step is making a copy of our data then the cleaning technique Define, code, test

# %%
df_clean = df.copy()

# %% [markdown]
# Problem:
# * start_time and end_time columns in object dtype
# * start_station_id and end_station_id columns in int64 dtype
# * start_station_latitude, start_station_longitude, end_station_latitude, and * end_station_longitude columns in float64 dtype
# * bike_id column in int64 dtype
# * user_type in object dtype

# %%
# Define: Change columns dtype based on it's value

# Code
dtype= {'start_time': 'datetime64', 
        'end_time': 'datetime64',
        
        'start_station_id': 'object',
        'end_station_id': 'object',
        
        'start_station_latitude': 'object',
        'start_station_longitude':  'object',
        'end_station_latitude':  'object',
        'end_station_longitude':  'object',
        
        'bike_id': 'object',
        'user_type': 'category'}

df_clean = df_clean.astype(dtype)

# Test
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183412 non-null  int64
#  1   start_time               183412 non-null  datetime64[ns]
#  2   end_time                 183412 non-null  datetime64[ns]
#  3   start_station_id         183215 non-null  object
#  4   start_station_name       183215 non-null  object
#  5   start_station_latitude   183412 non-null  object
#  6   start_station_longitude  183412 non-null  object
#  7   end_station_id           183215 non-null  object
#  8   end_station_name         183215 non-null  object
#  9   end_station_latitude     183412 non-null  object
#  10  end_station_longitude    183412 non-null  object
#  11  bike_id                  183412 non-null  object
#  12  user_type                183412 non-null  category
# ...

# %% [markdown]
# Problem:
# * Dropping NaN Values

# %%
# Define : *Some Null values can be viewed in birth_year, gender columns, stations (start, end).*

# Code
df_clean = df_clean.dropna()
# Test
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174952 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             174952 non-null  int64
#  1   start_time               174952 non-null  datetime64[ns]
#  2   end_time                 174952 non-null  datetime64[ns]
#  3   start_station_id         174952 non-null  object
#  4   start_station_name       174952 non-null  object
#  5   start_station_latitude   174952 non-null  object
#  6   start_station_longitude  174952 non-null  object
#  7   end_station_id           174952 non-null  object
#  8   end_station_name         174952 non-null  object
#  9   end_station_latitude     174952 non-null  object
#  10  end_station_longitude    174952 non-null  object
#  11  bike_id                  174952 non-null  object
#  12  user_type                174952 non-null  category
# ...

# %% [markdown]
# Problem: Creating Age colmun from the year of birth column

# %%
# Define: *for analysis purpose it would be better to have the age instead of the year of birth*
# code
df_clean['age'] = 2019 - df_clean['member_birth_year']
df_clean.drop('member_birth_year', axis=1, inplace=True)
# test
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174952 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             174952 non-null  int64
#  1   start_time               174952 non-null  datetime64[ns]
#  2   end_time                 174952 non-null  datetime64[ns]
#  3   start_station_id         174952 non-null  object
#  4   start_station_name       174952 non-null  object
#  5   start_station_latitude   174952 non-null  object
#  6   start_station_longitude  174952 non-null  object
#  7   end_station_id           174952 non-null  object
#  8   end_station_name         174952 non-null  object
#  9   end_station_latitude     174952 non-null  object
#  10  end_station_longitude    174952 non-null  object
#  11  bike_id                  174952 non-null  object
#  12  user_type                174952 non-null  category
# ...

# %% [markdown]
# Problem: delete all ages Above 90 take into consideration the date of the data (2019)

# %%
# Define: delete all ages Above 90 take into consideration the date of the data (2019)

# Code
# Remove outliers in Birth year column 
ids = df_clean[df_clean['age']>90].index
df_clean = df_clean.drop(index=ids)
# Test
df_clean.age.describe()
# Out:
# count    174875.000000
# mean         34.160274
# std           9.968641
# min          18.000000
# 25%          27.000000
# 50%          32.000000
# 75%          39.000000
# max          89.000000
# Name: age, dtype: float64

# %% [markdown]
# Problem: Making start and end time more specific

# %%
# Define Add day, week_day, hour, day_part columns from the start_time and end_time columns
# Code
time_intervals = [0,4,12,17,22,23]
time_labels=['Night/Early Morning', 'Morning', 'Afternoon', 'Evening', 'Night']
# Creating Features from time 
df_clean['start_day'] = df_clean['start_time'].dt.day
df_clean['start_day_of_week'] = df_clean['start_time'].dt.day_name()
df_clean['start_hour'] = df_clean['start_time'].dt.hour
df_clean['end_day'] = df_clean['end_time'].dt.day
df_clean['end_day_of_week'] = df_clean['end_time'].dt.day_name()
df_clean['end_hour'] = df_clean['end_time'].dt.hour
df_clean['month'] = df_clean['start_time'].dt.month_name()

df_clean.drop('end_time', axis=1, inplace=True)
df_clean.drop('start_time', axis=1, inplace=True)

# Test
df_clean.head(3)
# Out:
#    duration_sec start_station_id  \
# 0         52185             21.0
# 2         61854             86.0
# 3         36490            375.0
#
#                                  start_station_name start_station_latitude  \
# 0  Montgomery St BART Station (Market St at 2nd St)              37.789625
# 2                           Market St at Dolores St              37.769305
# 3                           Grove St at Masonic Ave              37.774836
#
#   start_station_longitude end_station_id  \
# 0             -122.400811           13.0
# 2             -122.426826            3.0
# 3             -122.446546           70.0
#
#                                end_station_name end_station_latitude  \
# 0                Commercial St at Montgomery St            37.794231
# 2  Powell St BART Station (Market St at 4th St)            37.786375
# 3                        Central Ave at Fell St            37.773311
#
# ...

# %%
# Define creating categorical variable using pandas
# Code
for hour in ['start_hour', 'end_hour']:
  df_clean[f'{hour.split("_")[0]}_day_part']=pd.cut(df_clean[hour],
                                                    bins=time_intervals,
                                                    labels=time_labels,
                                                    include_lowest=True,
                                                    )
  # test                                        
  display(df_clean[f'{hour.split("_")[0]}_day_part'].value_counts().sort_index().to_frame())
# Out:
#                      start_day_part
# Night/Early Morning            2163
# Morning                       73443
# Afternoon                     58771
# Evening                       38926
# Night                          1572
#                      end_day_part
# Night/Early Morning          2303
# Morning                     71833
# Afternoon                   56896
# Evening                     42096
# Night                        1747

# %% [markdown]
# Problem: Drop Gender Outliers "Other" since it represents less than 2%

# %%
# define removing outliers from DF
# Code
ids = df_clean[df_clean['member_gender']=='Other'].index
df_clean = df_clean.drop(index=ids)
# Test
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171230 entries, 0 to 183411
# Data columns (total 23 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             171230 non-null  int64
#  1   start_station_id         171230 non-null  object
#  2   start_station_name       171230 non-null  object
#  3   start_station_latitude   171230 non-null  object
#  4   start_station_longitude  171230 non-null  object
#  5   end_station_id           171230 non-null  object
#  6   end_station_name         171230 non-null  object
#  7   end_station_latitude     171230 non-null  object
#  8   end_station_longitude    171230 non-null  object
#  9   bike_id                  171230 non-null  object
#  10  user_type                171230 non-null  category
#  11  member_gender            171230 non-null  object
#  12  bike_share_for_all_trip  171230 non-null  object
# ...

# %% [markdown]
# # 3 Exploration

# %% [markdown]
# * ### What is the structure of your dataset?
#
# There are 171230 diamonds in the dataset with 25 features
#
# * #### What is/are the main feature(s) of interest in your dataset?
#
# The main features of interest in this dataset is duration_sec, month, start and end different times and user_type column finally gender.
#
#
# * #### What features in the dataset do you think will help support your investigation into your feature(s) of interest?
# Location, Age, Gender, User type, Bike Share status, Time

# %% [markdown]
# ## 3.1 Univariate Exploration
#
# I'll start by looking at the distribution of the main variable of interest:
# duration_sec

# %%
df_clean['duration_sec'].plot()

# %%
binsize = 500
bins = np.arange(0, df_clean['duration_sec'].max()+binsize, binsize)

plt.figure(figsize=[8, 5])
plt.hist(data = df_clean, x = 'duration_sec', bins = bins)
plt.title('Distribution of Trip Durations')
plt.xlabel('Duration (sec)')
plt.ylabel('Number of Trips')
plt.axis([-100, 6000, 0, 90000])
plt.show()

# %% [markdown]
# Trip duration is mostly concentrated on the lower spectrum. Most of the values are less than 2000 seconds. The longest Trip duration is 5000 seconds

# %% [markdown]
# Next up, the next variable of interest: user_type.

# %%
plt.figure(figsize=(10,6))     
base_color = sns.color_palette()[0]
ax = sns.countplot(data=df_clean, x ='user_type')

# add annotations
n_points = df_clean.shape[0]
cat_counts = df_clean['user_type'].value_counts()
locs, labels = plt.xticks() # get the current tick locations and labels

# loop through each pair of locations and labels
for loc, label in zip(locs, labels):

    # get the text property for the label to get the correct count
    count = cat_counts[label.get_text()]
    pct_string = '{}'.format(count)

    # print the annotation just below the top of the bar
    plt.text(loc, count-8, pct_string, va='top', ha='center', color = 'black', fontsize=12)

plt.title('Bike User Count')

# Remove unnecessary features 
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['left'].set_visible(False)
plt.yticks([])
plt.ylabel('')
plt.xlabel('')

# Show the plot
plt.show();

# %%
ax = sns.countplot(x="user_type", data=df_clean)

# This function is used to change the count plot numbers into percentages
def without_hue(plot, feature):
    total = len(feature)
    for p in plot.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        plot.annotate(percentage, (x, y), size = 12, va='bottom', ha='center')

without_hue(ax, df_clean.user_type)

# %% [markdown]
# From the total entry of rows in 2019 data, less than 10% users are customers.

# %% [markdown]
# Now let's take a look at the age distribution

# %%
sns.displot(df_clean, x="age", binwidth=3, bins=20, discrete=True, height=7, kde=True);

# %%
plt.title('Most Ages', fontsize=15)
df_clean.age.value_counts(ascending=True).tail(10).plot.barh();

# %% [markdown]
# The next variable will be the time we will visualize start and end time variables

# %%
# Start & End Day
nrows, ncols = 1, 2
cols = df.columns 
color = sns.color_palette()[0]
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20,10))
sns.distplot(data=df_clean['start_day'], color=color, ax = ax[1],kde=True);
sns.distplot(data=df_clean['end_day'],color=color, ax = ax[0],kde=True);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Start & End Hours
nrows, ncols = 1, 2
cols = df.columns 
color = sns.color_palette()[0]
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20,10))
sns.distplot(data=df_clean['start_hour'], color=color, ax = ax[1],kde=True);
sns.distplot(data=df_clean['end_hour'],color=color, ax = ax[0],kde=True);
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
# Start & End Day pf weeks
nrows, ncols = 1, 2
color = sns.color_palette()[0]
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20,10))

plot1 = sns.countplot(data=df_clean['start_day_of_week'], order=day_order, color=color, ax = ax[1]);
without_hue(plot1, df_clean.start_day_of_week)
plot2 = sns.countplot(data=df_clean['end_day_of_week'], order=day_order, color=color, ax = ax[0]);
without_hue(plot2, df_clean.end_day_of_week)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
df_clean.month.value_counts()
# Out:
# February    171230
# Name: month, dtype: int64

# %% [markdown]
# For the start and end day the plots looks almost identical, but for the start and end hour there is an obvious difference specially in the hour 9 and 22 and the rest similar. For the week day the most active day thursday and the least active are sunday and saturday

# %% [markdown]
# The last variable we can check for is the end and start station

# %%
plt.title('Most Popular Start Stations', fontsize=15)
df_clean.start_station_name.value_counts(ascending=True).tail(10).plot.barh();

# %%
plt.title('Most Popular End Stations', fontsize=15)
df_clean.end_station_name.value_counts(ascending=True).tail(10).plot.barh();

# %% [markdown]
# ### Discuss the distribution(s) of your variable(s) of interest. Were there any unusual points? Did you need to perform any transformations?
#
# The distrubution of the data is clearly good we don't have outliers the only variable with a skewed histograme is the duration and we didn't preform any transformation since it is clearly skewed.
#
# ### Of the features you investigated, were there any unusual distributions? Did you perform any operations on the data to tidy, adjust, or change the form of the data? If so, why did you do this?
#
# yes we did some data assessing and cleaning to treat the following problems:
#
# * start_time and end_time columns in object dtype
# * start_station_id and end_station_id columns in int64 dtype
# * start_station_latitude, start_station_longitude, end_station_latitude, and end_station_longitude columns in float64 dtype
# * bike_id column in int64 dtype
# * user_type in object dtype
# * Adding Age column
# * drop NaN values
# * delete all ages Above 90 take into consideration the date of the data (2019)
# * Add day, week_day, hour, day_part columns from the start_time and end_time columns
# * Drop Gender Outliers "Other" since it represents less than 2%
#
# We did those operations to make our data tidy and get better analysis results.

# %% [markdown]
# ## 3.2 Bivariate Exploration

# %% [markdown]
# The first values we gonna check are duration and age

# %%
plt.figure(figsize=[12,5])

plt.subplot(1, 2, 1)
plt.scatter(df_clean['age'], df_clean['duration_sec'], alpha = 0.25, marker = '.' )
plt.axis([18, 90, 60, df_clean['duration_sec'].quantile(0.95)])
plt.xlabel('Age (years)')
plt.ylabel('Duaration (sec)')

plt.subplot(1, 2, 2)
bins_y = np.arange(60, df_clean['duration_sec'].quantile(0.95)+60, 60)
bins_x = np.arange(18, 90+1, 10)
plt.hist2d(data=df_clean,x='age', y='duration_sec',
           bins = [bins_x, bins_y])
plt.colorbar(ticks=[10000, 20000, 30000, 40000]);
plt.show()

# %% [markdown]
# By looking at the plots it is clear that most frequent users of bikes are aged between 20 and 50. Higher duration is clocked by younger members.

# %% [markdown]
# Next, we are looking up user_type and duration then user_type with time

# %%
sns.catplot(data=df_clean, x='user_type', ax = ax[0], y='duration_sec', kind='bar');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try barplot
#   warnings.warn(msg, UserWarning)

# %%
# user type with the start an end day
nrows, ncols = 1, 2
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20,10))

plot1 = sns.countplot(data=df_clean, x='start_day_of_week', order=day_order, ax = ax[1], hue='user_type');
without_hue(plot1, df_clean.start_day_of_week)

plot2 = sns.countplot(data=df_clean, x='end_day_of_week', order=day_order, ax = ax[0], hue='user_type');
without_hue(plot2, df_clean.end_day_of_week)

# %%
# user type with the start an end hour
nrows, ncols = 1, 2
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20,10))

plot1 = sns.countplot(data=df_clean, x='start_hour', ax = ax[1], hue='user_type');
without_hue(plot1, df_clean.start_hour)

plot2 = sns.countplot(data=df_clean, x='end_hour', ax = ax[0], hue='user_type');
without_hue(plot2, df_clean.end_hour)

# %%
# user type with the start and end day part
nrows, ncols = 1, 2
fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=(20,10))
plot1 = sns.countplot(data=df_clean, x='start_day_part', ax = ax[1], hue='user_type');
without_hue(plot1, df_clean.start_day_part)
plot2 = sns.countplot(data=df_clean, x='end_day_part', ax = ax[0], hue='user_type');
without_hue(plot2, df_clean.end_day_part)

# %% [markdown]
# it is so clear that customer count is less than subscriber but for the rid duration customers are way higher thant subscriber

# %% [markdown]
# Next checking time with duration

# %%
# Start & End day with duration
data = df_clean[["start_day_of_week", "end_day_of_week", "duration_sec"]]
# melting start and end day of the week into categories 
data = data.melt(id_vars=['duration_sec'], var_name='start/end', value_name='day')
data.head(3)
# Out:
#    duration_sec          start/end       day
# 0         52185  start_day_of_week  Thursday
# 1         61854  start_day_of_week  Thursday
# 2          1585  start_day_of_week  Thursday

# %%
# plotting
g=sns.relplot(
    data=data, 
    x='day', 
    y='duration_sec',
    col="start/end",
    kind="line");
# Adding Main title
plt.suptitle("Distribution of ride duration by start and end ride day of the week")
## Plot Dimensions
g.fig.set_size_inches(14,8);

# %%
# Start & End hour with duration
data = df_clean[["start_hour", "end_hour", "duration_sec"]]
# melting start and end hour into categories 
data = data.melt(id_vars=['duration_sec'], var_name='start/end', value_name='hour')
data.head(3)
# Out:
#    duration_sec   start/end  hour
# 0         52185  start_hour    17
# 1         61854  start_hour    12
# 2          1585  start_hour    23

# %%
# plotting
g=sns.relplot(
    data=data, 
    x='hour', 
    y='duration_sec',
    col="start/end",
    kind="line"
    );
# Adding Main title
plt.suptitle("Distribution of ride duration by start and end ride hour")
## Plot Dimensions
g.fig.set_size_inches(14,8);

# %% [markdown]
# The duration is very high in the weekend than it is in the other days
# Also people who ride before 5 with the most ride duration

# %% [markdown]
# our last variables are gender and duration

# %%
sns.catplot(data=df_clean, x='member_gender', ax = ax[0], y='duration_sec');
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3775: UserWarning: catplot is a figure-level function and does not accept target axes. You may wish to try stripplot
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Female ride duration seems little bit longer than mans in general but as shown in the plot there are some values in the man line that superpass 80000 second so in general the two variables are so close

# %% [markdown]
# ### Talk about some of the relationships you observed in this part of the investigation. How did the feature(s) of interest vary with other features in the dataset?
#
# * There is multiple observations such the type of user and duration were customer riding duration tend to be more than subscribers
# * The weekend days duration of riding is way more than other days
# * People who are at age 20 to around 50 ride duration is high and people from 20 to 30 are the highest

# %% [markdown]
# ## 3.3 Multivariate Exploration
#
# Create plots of three or more variables to investigate your data even further.

# %% [markdown]
# ### 3.3.1 Age and duration with Gender or user type

# %%
# Age and duration with gender
sns.scatterplot(data=df_clean,y='duration_sec',x='age', alpha=0.5, hue='member_gender', legend='full')

# %% [markdown]
# Under the duration of 20000 and between age 20 and 60 it is clear that both male and are close. However Above 60000 second in the same range of age male have littile more values. But it is clear for both genders above the age of 60 no values above 20000

# %%
# Age and duration with user type
sns.scatterplot(data=df_clean,y='duration_sec',x='age', alpha=0.5, hue='user_type', legend='full')

# %% [markdown]
# most of customer and subcribers rides are under 20000 in all ages. However above the age of 70 most riders are subscribers

# %% [markdown]
# ### Time and duration with gender and user_type

# %%
# Start and End day
sns.relplot(
    data=df_clean, kind="line",
    x="start_day", y="duration_sec", col="member_gender",
    hue="user_type", style="user_type", ax = ax[1], markers=True,
)
sns.relplot(
    data=df_clean, kind="line",
    x="end_day", y="duration_sec", col="member_gender",
    hue="user_type", style="user_type", ax = ax[0], markers=True,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/relational.py:943: UserWarning: relplot is a figure-level function and does not accept the `ax` parameter. You may wish to try lineplot
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/relational.py:943: UserWarning: relplot is a figure-level function and does not accept the `ax` parameter. You may wish to try lineplot
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# * For male customers most riding duration when the customer starts the ride in the second week of the month
# * For male customers most rides duration ends with the 10th of the month
# * For Female customers the rides with the most duration are in the second week of the month too
# * For Female customers rides ends between the 10th and the 15th are with the most duration
# * Subscribers both male and female don't give that much of details

# %%
# Start and End day
sns.relplot(
    data=df_clean, kind="line",
    x="start_hour", y="duration_sec", col="member_gender",
    hue="user_type", style="user_type", ax = ax[1], markers=True,
)
sns.relplot(
    data=df_clean, kind="line",
    x="end_hour", y="duration_sec", col="member_gender",
    hue="user_type", style="user_type", ax = ax[0], markers=True,
)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/relational.py:943: UserWarning: relplot is a figure-level function and does not accept the `ax` parameter. You may wish to try lineplot
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/relational.py:943: UserWarning: relplot is a figure-level function and does not accept the `ax` parameter. You may wish to try lineplot
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# * Male customers rides with the most duration Starts before 5 and ends around 5
# * Female customers rides with the msot duration starts also before 5 but ends also bfore 5
# * Females who starts thier rides before 5 and those who ends thier rides before 5 tend to ride more than male in all times
# * Most duration rides by female subscribers ends before 5

# %%
# selecting columns to plot 
cols=['start_day_of_week', 'end_day_of_week', 'duration_sec', 'member_gender']
# creating new data
plot_data = df_clean[cols]
# Melting data
plot_data = plot_data.melt(id_vars=['duration_sec', 'member_gender'], var_name='start/end', value_name='day')
plot_data.head(2)
# Out:
#    duration_sec member_gender          start/end       day
# 0         52185          Male  start_day_of_week  Thursday
# 1         61854          Male  start_day_of_week  Thursday

# %%
## Plotting
sns.catplot(
    data=plot_data, 
    x="day", 
    y="duration_sec", 
    hue="member_gender",
    col="start/end",
    order=day_order,
    kind="bar",
)

# %% [markdown]
# * Male and females most duration rides are in the Weekend
# * in All week days female riding duration is bigger than male riding duration

# %%
# selecting columns to plot 
cols=['start_day_of_week', 'end_day_of_week', 'duration_sec', 'user_type']
# creating new data
plot_data = df_clean[cols]
# Melting data
plot_data = plot_data.melt(id_vars=['duration_sec', 'user_type'], var_name='start/end', value_name='day')
plot_data.head(2)
# Out:
#    duration_sec user_type          start/end       day
# 0         52185  Customer  start_day_of_week  Thursday
# 1         61854  Customer  start_day_of_week  Thursday

# %%
## Plotting
sns.catplot(
    data=plot_data, 
    x="day", 
    y="duration_sec", 
    hue="user_type",
    col="start/end",
    order=day_order,
    kind="bar",
)

# %% [markdown]
# * Subscribers riding is stable in all the week
# * Customers riding duration peak is in the weekend
# * Customers riding duration are higher than subscribers in the whole week

# %% [markdown]
# ####  Talk about some of the relationships you observed in this part of the investigation. Were there features that strengthened each other in terms of looking at your feature(s) of interest?
# Yes. The type of user and the gender has an influence on the use of this service.
# * **Duration of use:**
#  * *Subscribers tends to have stable duration usage than Customers*
#  * *Subscribers duration usage is way less than Customers*
#  * *Subscribers usage is more than Customers*
#  * *Female rides duration are more than male durations*
#
# * **Days of use**
#  * *Subscribers tends to use the service in weekdays, in contrast Customers focusses more on weekends*
#  * *the first two weeks of the month are with the most rides durations*
# * **Hours of use**
#  * Customers Male and Females peak duration rides before 5.
#  * Customers Male and Females peak duration rides ends before 5.
#  * Male customers duration riding is low and stable and opposite for female customers

# %% [markdown]
# #### Were there any interesting or surprising interactions between features?
#
# * It was so surprising to find that the of riding duration is between 3 am and 5 am for male and female customers and subscribers

# %%
# Export cleaned dataframe to CSV file for slide deck

# Code
df_clean.to_csv('201902-fordgobike-tripdata_clean.csv', index=None)
df_check = pd.read_csv('201902-fordgobike-tripdata_clean.csv')

# Test
df_check
